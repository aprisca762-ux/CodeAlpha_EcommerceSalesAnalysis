# %%
df.to_csv("CodeAlpha_EcommerceSales.csv", index=False)
print("Dataset saved successfully!")
# Out:
# Dataset saved successfully!

# %%
print("===== KEY FINDINGS =====")

print("1. Laptop generated the highest product sales at ₦6,350.")
print("2. Mouse generated the lowest product sales at ₦360.")
print("3. Electronics generated more sales than Accessories.")
print("4. The dataset contains 18 records after removing duplicates.")
print("5. Total sales were ₦20,730, while total profit was ₦4,334.")
# Out:
# ===== KEY FINDINGS =====
# 1. Laptop generated the highest product sales at ₦6,350.
# 2. Mouse generated the lowest product sales at ₦360.
# 3. Electronics generated more sales than Accessories.
# 4. The dataset contains 18 records after removing duplicates.
# 5. Total sales were ₦20,730, while total profit was ₦4,334.

# %%
print("===== E-COMMERCE SALES ANALYSIS =====")
print()
print("Total Sales:", df["Sales"].sum())
print("Total Profit:", df["Profit"].sum())
print("Total Quantity Sold:", df["Quantity"].sum())
print("Number of Products:", df["Product"].nunique())
print("Number of Regions:", df["Region"].nunique())
print("Number of Categories:", df["Category"].nunique())
print("Number of Records After Cleaning:", len(df))
# Out:
# ===== E-COMMERCE SALES ANALYSIS =====
#
# Total Sales: 20730
# Total Profit: 4334
# Total Quantity Sold: 66
# Number of Products: 7
# Number of Regions: 4
# Number of Categories: 2
# Number of Records After Cleaning: 20

# %%
category_profit = df.groupby("Category")["Profit"].sum()

plt.figure(figsize=(8,5))
category_profit.plot(kind="bar")
plt.title("Profit by Category")
plt.xlabel("Category")
plt.ylabel("Profit")
plt.xticks(rotation=0)
plt.show()

# %%
product_profit = df.groupby("Product")["Profit"].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
product_profit.plot(kind="bar")
plt.title("Profit by Product")
plt.xlabel("Product")
plt.ylabel("Profit")
plt.xticks(rotation=45)
plt.show()

# %%
product_sales = df.groupby("Product")["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(10,6))
product_sales.plot(kind="bar")
plt.title("Sales by Product")
plt.xlabel("Product")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %%
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)

plt.figure(figsize=(8,5))
region_sales.plot(kind="bar")
plt.title("Sales by Region")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.xticks(rotation=0)
plt.show()

# %%
import matplotlib.pyplot as plt

category_sales = df.groupby("Category")["Sales"].sum()

plt.figure(figsize=(8,5))
category_sales.plot(kind="bar")
plt.title("Sales by Category")
plt.xlabel("Category")
plt.ylabel("Sales")
plt.xticks(rotation=0)
plt.show()

# %%
print("Average Sales:", df["Sales"].mean())
print("Average Profit:", df["Profit"].mean())
print("Average Quantity:", df["Quantity"].mean())
# Out:
# Average Sales: 1036.5
# Average Profit: 216.7
# Average Quantity: 3.3

# %%
region_analysis = df.groupby("Region")[["Sales", "Profit"]].sum().sort_values("Sales", ascending=False)
region_analysis
# Out:
#                Sales  Profit
# Region
# Lagos           9340    2002
# Ibadan          6000    1200
# Abuja           4370     916
# Port Harcourt   1020     216

# %%
product_profit = df.groupby("Product")["Profit"].sum().sort_values(ascending=False)
product_profit
# Out:
# Product
# Laptop        1270
# Phone         1120
# Tablet         840
# Monitor        540
# Headphones     336
# Keyboard       120
# Mouse          108
# Name: Profit, dtype: int64

# %%
region_sales = df.groupby("Region")["Sales"].sum().sort_values(ascending=False)
region_sales
# Out:
# Region
# Lagos            9340
# Ibadan           6000
# Abuja            4370
# Port Harcourt    1020
# Name: Sales, dtype: int64

# %%
category_sales = df.groupby("Category")["Sales"].sum().sort_values(ascending=False)

category_sales
# Out:
# Category
# Electronics    19970
# Accessories      760
# Name: Sales, dtype: int64

# %%
product_sales = df.groupby("Product")["Sales"].sum().sort_values(ascending=False)

product_sales
# Out:
# Product
# Laptop        6350
# Phone         5600
# Tablet        4200
# Monitor       2700
# Headphones    1120
# Keyboard       400
# Mouse          360
# Name: Sales, dtype: int64

# %%
print("Total Sales:", df["Sales"].sum())
print("Total Profit:", df["Profit"].sum())
print("Total Quantity Sold:", df["Quantity"].sum())
# Out:
# Total Sales: 20730
# Total Profit: 4334
# Total Quantity Sold: 66

# %%
df.describe()
# Out:
#         Quantity        Sales      Profit
# count  20.000000    20.000000   20.000000
# mean    3.300000  1036.500000  216.700000
# std     1.657519   717.490326  133.828287
# min     1.000000   120.000000   36.000000
# 25%     2.000000   380.000000  114.000000
# 50%     3.000000   900.000000  180.000000
# 75%     4.250000  1800.000000  360.000000
# max     7.000000  2100.000000  420.000000

# %%
df.shape
# Out:
# (20, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Product   20 non-null     object
#  1   Category  20 non-null     object
#  2   Region    20 non-null     object
#  3   Quantity  20 non-null     int64
#  4   Sales     20 non-null     int64
#  5   Profit    20 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 1.1+ KB

# %%
df.isnull().sum()
# Out:
# Product     0
# Category    0
# Region      0
# Quantity    0
# Sales       0
# Profit      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (18, 6)

# %%
data = {
    "Product": [
        "Laptop", "Phone", "Headphones", "Laptop", "Tablet",
        "Keyboard", "Monitor", "Mouse", "Phone", "Laptop",
        "Tablet", "Headphones", "Monitor", "Keyboard", "Mouse",
        "Laptop", "Phone", "Tablet", "Monitor", "Headphones"
    ],
    "Category": [
        "Electronics", "Electronics", "Electronics", "Electronics", "Electronics",
        "Accessories", "Electronics", "Accessories", "Electronics", "Electronics",
        "Electronics", "Electronics", "Electronics", "Accessories", "Accessories",
        "Electronics", "Electronics", "Electronics", "Electronics", "Electronics"
    ],
    "Region": [
        "Lagos", "Abuja", "Lagos", "Ibadan", "Lagos",
        "Abuja", "Lagos", "Port Harcourt", "Lagos", "Abuja",
        "Ibadan", "Lagos", "Port Harcourt", "Lagos", "Abuja",
        "Lagos", "Ibadan", "Lagos", "Abuja", "Lagos"
    ],
    "Quantity": [
        2, 3, 5, 1, 4, 3, 2, 6, 2, 1,
        3, 4, 2, 5, 7, 2, 3, 2, 4, 5
    ],
    "Sales": [
        1800, 2100, 400, 1800, 1400,
        180, 900, 120, 1400, 950,
        2100, 320, 900, 220, 240,
        1800, 2100, 700, 900, 400
    ],
    "Profit": [
        360, 420, 120, 360, 280,
        54, 180, 36, 280, 190,
        420, 96, 180, 66, 72,
        360, 420, 140, 180, 120
    ]
}

df = pd.DataFrame(data)

df.head()
# Out:
#       Product     Category  Region  Quantity  Sales  Profit
# 0      Laptop  Electronics   Lagos         2   1800     360
# 1       Phone  Electronics   Abuja         3   2100     420
# 2  Headphones  Electronics   Lagos         5    400     120
# 3      Laptop  Electronics  Ibadan         1   1800     360
# 4      Tablet  Electronics   Lagos         4   1400     280

# %%
import pandas as pd
